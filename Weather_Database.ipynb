# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create a set of random lat and long combos
lats = np.random.uniform(-90.000, 90.000, size = 2000)
lngs = np.random.uniform(-180.000, 180.000, size = 2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# create a list of coordinates
coordinates = list(lats_lngs)

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/kalymalechek/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/kalymalechek/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
from citipy import citipy

# %%
# create a list for holding the cities
cities = []

# id the nearest city for each coordinate combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # if the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)
# print the city count to confirm sufficient list size
len(cities)
# Out:
# 773

# %%
# import the requests library.
import requests

# import the API key.
from config2 import weather_api_key

# %%
# starting url for weather map api call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# import the datetime module
from datetime import datetime

# %%
# create a new list to hold the weather data
city_data = []
# print the beginning
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# loop through cities list
for i, city in enumerate(cities):
    
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the url, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # add 1 to the record count
    record_count += 1
    # run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "CurrentDescription": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | uglovskoye
# Processing Record 5 of Set 1 | constitucion
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | mogadishu
# Processing Record 12 of Set 1 | thompson
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | touros
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | basavana bagevadi
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | mancora
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 1 | fuxin
# Processing Record 23 of Set 1 | ledyard
# Processing Record 24 of Set 1 | berdigestyakh
# Processing Record 25 of Set 1 | riyadh
# Processing Record 26 of Set 1 | tasiilaq
# Processing Record 27 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | touho
# Processing Record 29 of Set 1 | nicolas bravo
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | los llanos de aridane
# Processing Record 32 of Set 1 | baruun-urt
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | charters towers
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | laguna
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 1 | rocky mount
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | kongwa
# Processing Record 44 of Set 1 | kuusamo
# Processing Record 45 of Set 1 | xining
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | waipawa
# Processing Record 48 of Set 1 | divnogorsk
# Processing Record 49 of Set 1 | namanga
# Processing Record 50 of Set 1 | saldanha
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | bakchar
# Processing Record 3 of Set 2 | diamantino
# Processing Record 4 of Set 2 | port lincoln
# Processing Record 5 of Set 2 | poplar bluff
# Processing Record 6 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 2 | alyangula
# Processing Record 8 of Set 2 | pantai remis
# Processing Record 9 of Set 2 | rumboci
# Processing Record 10 of Set 2 | severo-kurilsk
# Processing Record 11 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 13 of Set 2 | kaoma
# Processing Record 14 of Set 2 | kirakira
# Processing Record 15 of Set 2 | bilma
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | idah
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | fort nelson
# Processing Record 20 of Set 2 | asau
# Processing Record 21 of Set 2 | seymchan
# Processing Record 22 of Set 2 | pochutla
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | port-gentil
# Processing Record 25 of Set 2 | torbay
# Processing Record 26 of Set 2 | sanchor
# Processing Record 27 of Set 2 | kushmurun
# Processing Record 28 of Set 2 | walvis bay
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | west plains
# Processing Record 33 of Set 2 | escanaba
# Processing Record 34 of Set 2 | najran
# Processing Record 35 of Set 2 | batagay-alyta
# Processing Record 36 of Set 2 | kutum
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | okahandja
# Processing Record 39 of Set 2 | nyrob
# Processing Record 40 of Set 2 | galveston
# Processing Record 41 of Set 2 | kampene
# Processing Record 42 of Set 2 | dampol
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | margate
# Processing Record 45 of Set 2 | wewak
# Processing Record 46 of Set 2 | saint-gabriel
# Processing Record 47 of Set 2 | jiangyou
# Processing Record 48 of Set 2 | udachnyy
# Processing Record 49 of Set 2 | monte alegre
# Processing Record 50 of Set 2 | srednekolymsk
# Processing Record 1 of Set 3 | pecos
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | naze
# Processing Record 4 of Set 3 | aripuana
# Processing Record 5 of Set 3 | jacareacanga
# Processing Record 6 of Set 3 | sibolga
# Processing Record 7 of Set 3 | georgetown
# Processing Record 8 of Set 3 | kamaishi
# Processing Record 9 of Set 3 | konongo
# Processing Record 10 of Set 3 | te anau
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | nikolskoye
# Processing Record 14 of Set 3 | akyab
# Processing Record 15 of Set 3 | novoilinsk
# Processing Record 16 of Set 3 | celestun
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 3 | tambacounda
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | nome
# Processing Record 22 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 3 | roma
# Processing Record 24 of Set 3 | shingu
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | kailua
# Processing Record 27 of Set 3 | stornoway
# Processing Record 28 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 3 | petrykivka
# Processing Record 30 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | rio gallegos
# Processing Record 33 of Set 3 | iisalmi
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | kerman
# Processing Record 36 of Set 3 | jaguaruana
# Processing Record 37 of Set 3 | verkhnyaya inta
# Processing Record 38 of Set 3 | daru
# Processing Record 39 of Set 3 | balikpapan
# Processing Record 40 of Set 3 | kruisfontein
# Processing Record 41 of Set 3 | lompoc
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | bathsheba
# Processing Record 45 of Set 3 | la ronge
# Processing Record 46 of Set 3 | magalia
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | vaini
# Processing Record 49 of Set 3 | san patricio
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | pringsewu
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | plymouth
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 4 | elat
# Processing Record 8 of Set 4 | inirida
# Processing Record 9 of Set 4 | prieska
# Processing Record 10 of Set 4 | matsanga
# City not found. Skipping...
# Processing Record 11 of Set 4 | kodiak
# Processing Record 12 of Set 4 | pevek
# Processing Record 13 of Set 4 | filingue
# Processing Record 14 of Set 4 | mehamn
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | mayo
# Processing Record 17 of Set 4 | jobabo
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | port blair
# Processing Record 20 of Set 4 | ketchikan
# Processing Record 21 of Set 4 | saskylakh
# Processing Record 22 of Set 4 | jorochito
# Processing Record 23 of Set 4 | yacuiba
# Processing Record 24 of Set 4 | kodinar
# Processing Record 25 of Set 4 | praya
# Processing Record 26 of Set 4 | tual
# Processing Record 27 of Set 4 | rawson
# Processing Record 28 of Set 4 | grand gaube
# Processing Record 29 of Set 4 | ahvaz
# Processing Record 30 of Set 4 | moscow
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | khatanga
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | pacific grove
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | praia da vitoria
# Processing Record 37 of Set 4 | katsuura
# Processing Record 38 of Set 4 | muli
# Processing Record 39 of Set 4 | ichinoseki
# Processing Record 40 of Set 4 | sovetskiy
# Processing Record 41 of Set 4 | saint austell
# Processing Record 42 of Set 4 | iqaluit
# Processing Record 43 of Set 4 | villefontaine
# Processing Record 44 of Set 4 | caravelas
# Processing Record 45 of Set 4 | nantucket
# Processing Record 46 of Set 4 | ormara
# Processing Record 47 of Set 4 | beysehir
# Processing Record 48 of Set 4 | kamalapuram
# Processing Record 49 of Set 4 | avarua
# Processing Record 50 of Set 4 | grimmen
# Processing Record 1 of Set 5 | mersing
# Processing Record 2 of Set 5 | adiake
# Processing Record 3 of Set 5 | ponta delgada
# Processing Record 4 of Set 5 | klaksvik
# Processing Record 5 of Set 5 | vale da amoreira
# Processing Record 6 of Set 5 | liku
# Processing Record 7 of Set 5 | tari
# Processing Record 8 of Set 5 | sao filipe
# Processing Record 9 of Set 5 | coihaique
# Processing Record 10 of Set 5 | faanui
# Processing Record 11 of Set 5 | san cristobal
# Processing Record 12 of Set 5 | santa cruz
# Processing Record 13 of Set 5 | opuwo
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | svetlogorsk
# Processing Record 16 of Set 5 | obihiro
# Processing Record 17 of Set 5 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 18 of Set 5 | havre-saint-pierre
# Processing Record 19 of Set 5 | stoyba
# City not found. Skipping...
# Processing Record 20 of Set 5 | marsh harbour
# Processing Record 21 of Set 5 | saint george
# Processing Record 22 of Set 5 | ewa beach
# Processing Record 23 of Set 5 | mitchell
# Processing Record 24 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 5 | puquio
# Processing Record 26 of Set 5 | dongsheng
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | araouane
# Processing Record 29 of Set 5 | komsomolskiy
# Processing Record 30 of Set 5 | tiksi
# Processing Record 31 of Set 5 | soyo
# Processing Record 32 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 5 | dakar
# Processing Record 34 of Set 5 | lafiagi
# Processing Record 35 of Set 5 | mar del plata
# Processing Record 36 of Set 5 | ambagarh chauki
# Processing Record 37 of Set 5 | sur
# Processing Record 38 of Set 5 | mangrol
# Processing Record 39 of Set 5 | victoria
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | vanimo
# Processing Record 42 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 5 | belaya gora
# Processing Record 45 of Set 5 | tarakan
# Processing Record 46 of Set 5 | lagos
# Processing Record 47 of Set 5 | lasa
# Processing Record 48 of Set 5 | xam nua
# Processing Record 49 of Set 5 | korla
# Processing Record 50 of Set 5 | bavly
# Processing Record 1 of Set 6 | port shepstone
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | lanxi
# Processing Record 4 of Set 6 | mount isa
# Processing Record 5 of Set 6 | yellowknife
# Processing Record 6 of Set 6 | padang
# Processing Record 7 of Set 6 | camocim
# Processing Record 8 of Set 6 | pitea
# Processing Record 9 of Set 6 | kropotkin
# Processing Record 10 of Set 6 | baykit
# Processing Record 11 of Set 6 | qaanaaq
# Processing Record 12 of Set 6 | kaitangata
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | adre
# Processing Record 15 of Set 6 | tazovskiy
# Processing Record 16 of Set 6 | sayyan
# Processing Record 17 of Set 6 | redmond
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 6 | vila
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | canmore
# Processing Record 24 of Set 6 | athboy
# Processing Record 25 of Set 6 | vardo
# Processing Record 26 of Set 6 | paita
# Processing Record 27 of Set 6 | simao
# Processing Record 28 of Set 6 | bardiyah
# Processing Record 29 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 6 | tuktoyaktuk
# Processing Record 32 of Set 6 | turtas
# Processing Record 33 of Set 6 | presidente medici
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | vrangel
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | pokosnoye
# Processing Record 38 of Set 6 | christchurch
# Processing Record 39 of Set 6 | longyearbyen
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | anadyr
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | huicungo
# Processing Record 45 of Set 6 | marawi
# Processing Record 46 of Set 6 | samsun
# Processing Record 47 of Set 6 | levokumskoye
# Processing Record 48 of Set 6 | maniitsoq
# Processing Record 49 of Set 6 | santiago tuxtla
# Processing Record 50 of Set 6 | batagay
# Processing Record 1 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 7 | maridi
# Processing Record 3 of Set 7 | hofn
# Processing Record 4 of Set 7 | san quintin
# Processing Record 5 of Set 7 | cockburn town
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | kranjska gora
# Processing Record 8 of Set 7 | kulachi
# Processing Record 9 of Set 7 | sault sainte marie
# Processing Record 10 of Set 7 | ostrovnoy
# Processing Record 11 of Set 7 | bambous virieux
# Processing Record 12 of Set 7 | avera
# Processing Record 13 of Set 7 | nouadhibou
# Processing Record 14 of Set 7 | nabire
# Processing Record 15 of Set 7 | akcakoca
# Processing Record 16 of Set 7 | sulangan
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | angul
# Processing Record 19 of Set 7 | honningsvag
# Processing Record 20 of Set 7 | itarema
# Processing Record 21 of Set 7 | pisco
# Processing Record 22 of Set 7 | isangel
# Processing Record 23 of Set 7 | kavieng
# Processing Record 24 of Set 7 | guerrero negro
# Processing Record 25 of Set 7 | darnah
# Processing Record 26 of Set 7 | palmer
# Processing Record 27 of Set 7 | bobo dioulasso
# Processing Record 28 of Set 7 | salamiyah
# Processing Record 29 of Set 7 | port macquarie
# Processing Record 30 of Set 7 | sibu
# Processing Record 31 of Set 7 | bud
# Processing Record 32 of Set 7 | carbonia
# Processing Record 33 of Set 7 | aracaju
# Processing Record 34 of Set 7 | dingle
# Processing Record 35 of Set 7 | cap malheureux
# Processing Record 36 of Set 7 | san joaquin
# Processing Record 37 of Set 7 | passos
# Processing Record 38 of Set 7 | bailesti
# Processing Record 39 of Set 7 | candolim
# Processing Record 40 of Set 7 | sakakah
# Processing Record 41 of Set 7 | angoche
# Processing Record 42 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 7 | lalomanu
# City not found. Skipping...
# Processing Record 44 of Set 7 | puerto narino
# Processing Record 45 of Set 7 | clyde river
# Processing Record 46 of Set 7 | llanes
# Processing Record 47 of Set 7 | sergeyevka
# Processing Record 48 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 7 | kisangani
# Processing Record 50 of Set 7 | grindavik
# Processing Record 1 of Set 8 | evensk
# Processing Record 2 of Set 8 | salinopolis
# Processing Record 3 of Set 8 | poum
# Processing Record 4 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 8 | turinsk
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | keti bandar
# Processing Record 8 of Set 8 | vila franca do campo
# Processing Record 9 of Set 8 | hastings
# Processing Record 10 of Set 8 | nemuro
# Processing Record 11 of Set 8 | pittsfield
# Processing Record 12 of Set 8 | shatsk
# Processing Record 13 of Set 8 | portland
# Processing Record 14 of Set 8 | siva
# Processing Record 15 of Set 8 | leningradskiy
# Processing Record 16 of Set 8 | pascagoula
# Processing Record 17 of Set 8 | luderitz
# Processing Record 18 of Set 8 | bara
# Processing Record 19 of Set 8 | erenhot
# Processing Record 20 of Set 8 | tomatlan
# Processing Record 21 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 8 | shumerlya
# Processing Record 23 of Set 8 | eureka
# Processing Record 24 of Set 8 | wanaka
# Processing Record 25 of Set 8 | sao joao do piaui
# Processing Record 26 of Set 8 | kem
# Processing Record 27 of Set 8 | vao
# Processing Record 28 of Set 8 | jining
# Processing Record 29 of Set 8 | los alamos
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | bubaque
# Processing Record 32 of Set 8 | almenara
# Processing Record 33 of Set 8 | boguchar
# Processing Record 34 of Set 8 | barcelos
# Processing Record 35 of Set 8 | luwuk
# Processing Record 36 of Set 8 | shwebo
# Processing Record 37 of Set 8 | ballina
# Processing Record 38 of Set 8 | waingapu
# Processing Record 39 of Set 8 | beloha
# Processing Record 40 of Set 8 | kanepi
# Processing Record 41 of Set 8 | pirovskoye
# Processing Record 42 of Set 8 | inuvik
# Processing Record 43 of Set 8 | doka
# Processing Record 44 of Set 8 | pimentel
# Processing Record 45 of Set 8 | cradock
# Processing Record 46 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 8 | tarancon
# Processing Record 48 of Set 8 | prince rupert
# Processing Record 49 of Set 8 | warri
# Processing Record 50 of Set 8 | fuerte olimpo
# Processing Record 1 of Set 9 | sembakung
# Processing Record 2 of Set 9 | bonawon
# Processing Record 3 of Set 9 | nhulunbuy
# Processing Record 4 of Set 9 | kuito
# Processing Record 5 of Set 9 | curup
# Processing Record 6 of Set 9 | khotyn
# Processing Record 7 of Set 9 | port hardy
# Processing Record 8 of Set 9 | mazara del vallo
# Processing Record 9 of Set 9 | shimoda
# Processing Record 10 of Set 9 | maues
# Processing Record 11 of Set 9 | cairns
# Processing Record 12 of Set 9 | cherskiy
# Processing Record 13 of Set 9 | yongan
# Processing Record 14 of Set 9 | central point
# Processing Record 15 of Set 9 | teahupoo
# Processing Record 16 of Set 9 | wasilla
# Processing Record 17 of Set 9 | putina
# Processing Record 18 of Set 9 | pangody
# Processing Record 19 of Set 9 | valdez
# Processing Record 20 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 9 | ribeira grande
# Processing Record 22 of Set 9 | meinung
# City not found. Skipping...
# Processing Record 23 of Set 9 | qasigiannguit
# Processing Record 24 of Set 9 | santa isabel
# Processing Record 25 of Set 9 | bonthe
# Processing Record 26 of Set 9 | camabatela
# Processing Record 27 of Set 9 | vikesa
# Processing Record 28 of Set 9 | boone
# Processing Record 29 of Set 9 | alofi
# Processing Record 30 of Set 9 | bull savanna
# Processing Record 31 of Set 9 | puerto leguizamo
# Processing Record 32 of Set 9 | batemans bay
# Processing Record 33 of Set 9 | gander
# Processing Record 34 of Set 9 | hasaki
# Processing Record 35 of Set 9 | taltal
# Processing Record 36 of Set 9 | klyuchi
# Processing Record 37 of Set 9 | middle island
# Processing Record 38 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 9 | mizdah
# Processing Record 40 of Set 9 | kavaratti
# Processing Record 41 of Set 9 | hermiston
# Processing Record 42 of Set 9 | berlevag
# Processing Record 43 of Set 9 | road town
# Processing Record 44 of Set 9 | comendador
# Processing Record 45 of Set 9 | sabang
# Processing Record 46 of Set 9 | ust-omchug
# Processing Record 47 of Set 9 | coahuayana
# Processing Record 48 of Set 9 | saint-pierre
# Processing Record 49 of Set 9 | carlton
# Processing Record 50 of Set 9 | palu
# Processing Record 1 of Set 10 | manastirea casin
# City not found. Skipping...
# Processing Record 2 of Set 10 | namikupa
# Processing Record 3 of Set 10 | noumea
# Processing Record 4 of Set 10 | mana
# Processing Record 5 of Set 10 | tiarei
# Processing Record 6 of Set 10 | byron bay
# Processing Record 7 of Set 10 | tommot
# Processing Record 8 of Set 10 | bowen
# Processing Record 9 of Set 10 | santa comba
# Processing Record 10 of Set 10 | bonavista
# Processing Record 11 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 10 | nandurbar
# Processing Record 13 of Set 10 | lubao
# Processing Record 14 of Set 10 | salalah
# Processing Record 15 of Set 10 | maneadero
# Processing Record 16 of Set 10 | galion
# Processing Record 17 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 10 | guymon
# Processing Record 19 of Set 10 | nicoya
# Processing Record 20 of Set 10 | bismarck
# Processing Record 21 of Set 10 | huilong
# Processing Record 22 of Set 10 | zhangjiakou
# Processing Record 23 of Set 10 | guanica
# Processing Record 24 of Set 10 | burnie
# Processing Record 25 of Set 10 | haines junction
# Processing Record 26 of Set 10 | sitka
# Processing Record 27 of Set 10 | shu
# Processing Record 28 of Set 10 | naryan-mar
# Processing Record 29 of Set 10 | maningrida
# Processing Record 30 of Set 10 | kulhudhuffushi
# Processing Record 31 of Set 10 | flinders
# Processing Record 32 of Set 10 | dunmore town
# Processing Record 33 of Set 10 | bogotol
# Processing Record 34 of Set 10 | yar-sale
# Processing Record 35 of Set 10 | ucluelet
# Processing Record 36 of Set 10 | paso de carrasco
# Processing Record 37 of Set 10 | grand baie
# Processing Record 38 of Set 10 | werota
# Processing Record 39 of Set 10 | gat
# Processing Record 40 of Set 10 | quatre cocos
# Processing Record 41 of Set 10 | zhezkazgan
# Processing Record 42 of Set 10 | grafton
# Processing Record 43 of Set 10 | camana
# Processing Record 44 of Set 10 | sesvete
# Processing Record 45 of Set 10 | barsovo
# Processing Record 46 of Set 10 | itaituba
# Processing Record 47 of Set 10 | jumla
# Processing Record 48 of Set 10 | dunedin
# Processing Record 49 of Set 10 | porkhov
# Processing Record 50 of Set 10 | baghramyan
# Processing Record 1 of Set 11 | talaya
# Processing Record 2 of Set 11 | malatya
# Processing Record 3 of Set 11 | sola
# Processing Record 4 of Set 11 | tilichiki
# Processing Record 5 of Set 11 | shihezi
# Processing Record 6 of Set 11 | zhireken
# Processing Record 7 of Set 11 | horki
# Processing Record 8 of Set 11 | awjilah
# Processing Record 9 of Set 11 | petropavlovka
# Processing Record 10 of Set 11 | atasu
# Processing Record 11 of Set 11 | port talbot
# Processing Record 12 of Set 11 | atambua
# Processing Record 13 of Set 11 | orange cove
# Processing Record 14 of Set 11 | cayenne
# Processing Record 15 of Set 11 | kahului
# Processing Record 16 of Set 11 | le port
# Processing Record 17 of Set 11 | acaponeta
# Processing Record 18 of Set 11 | morant bay
# Processing Record 19 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 11 | san andres
# Processing Record 21 of Set 11 | aberdeen
# Processing Record 22 of Set 11 | boa vista
# Processing Record 23 of Set 11 | okhotsk
# Processing Record 24 of Set 11 | morehead
# Processing Record 25 of Set 11 | kupang
# Processing Record 26 of Set 11 | tsumeb
# Processing Record 27 of Set 11 | itapaci
# Processing Record 28 of Set 11 | cruden bay
# City not found. Skipping...
# Processing Record 29 of Set 11 | goderich
# Processing Record 30 of Set 11 | motygino
# Processing Record 31 of Set 11 | broome
# Processing Record 32 of Set 11 | acapulco
# Processing Record 33 of Set 11 | takoradi
# Processing Record 34 of Set 11 | primo tapia
# Processing Record 35 of Set 11 | storforshei
# Processing Record 36 of Set 11 | doctor juan leon mallorquin
# Processing Record 37 of Set 11 | moerai
# Processing Record 38 of Set 11 | pemangkat
# Processing Record 39 of Set 11 | sampit
# Processing Record 40 of Set 11 | kovdor
# Processing Record 41 of Set 11 | lensk
# Processing Record 42 of Set 11 | bintulu
# Processing Record 43 of Set 11 | namtsy
# Processing Record 44 of Set 11 | iracoubo
# Processing Record 45 of Set 11 | katiola
# Processing Record 46 of Set 11 | kirkuk
# Processing Record 47 of Set 11 | havelock
# Processing Record 48 of Set 11 | bichena
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 50 of Set 11 | ust-nera
# Processing Record 1 of Set 12 | nandi
# Processing Record 2 of Set 12 | nichinan
# Processing Record 3 of Set 12 | pasighat
# Processing Record 4 of Set 12 | buzdyak
# Processing Record 5 of Set 12 | tacuarembo
# Processing Record 6 of Set 12 | neuquen
# Processing Record 7 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 8 of Set 12 | namatanai
# Processing Record 9 of Set 12 | middletown
# Processing Record 10 of Set 12 | zonguldak
# Processing Record 11 of Set 12 | batsfjord
# Processing Record 12 of Set 12 | bodden town
# Processing Record 13 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 12 | veraval
# Processing Record 16 of Set 12 | muros
# Processing Record 17 of Set 12 | ellisras
# Processing Record 18 of Set 12 | puri
# Processing Record 19 of Set 12 | mandalgovi
# Processing Record 20 of Set 12 | kashi
# Processing Record 21 of Set 12 | buala
# Processing Record 22 of Set 12 | sioux lookout
# Processing Record 23 of Set 12 | tadine
# Processing Record 24 of Set 12 | nadvoitsy
# Processing Record 25 of Set 12 | iquitos
# Processing Record 26 of Set 12 | karratha
# Processing Record 27 of Set 12 | krasnovishersk
# Processing Record 28 of Set 12 | bonfim
# Processing Record 29 of Set 12 | mareeba
# Processing Record 30 of Set 12 | cordoba
# Processing Record 31 of Set 12 | kenai
# Processing Record 32 of Set 12 | sanmenxia
# Processing Record 33 of Set 12 | nuuk
# Processing Record 34 of Set 12 | mount gambier
# Processing Record 35 of Set 12 | hami
# Processing Record 36 of Set 12 | slave lake
# Processing Record 37 of Set 12 | saint anthony
# Processing Record 38 of Set 12 | amarillo
# Processing Record 39 of Set 12 | pulsano
# Processing Record 40 of Set 12 | palivere
# Processing Record 41 of Set 12 | moriyama
# Processing Record 42 of Set 12 | usvyaty
# Processing Record 43 of Set 12 | manakara
# Processing Record 44 of Set 12 | bugama
# Processing Record 45 of Set 12 | voyinka
# Processing Record 46 of Set 12 | lyaskelya
# Processing Record 47 of Set 12 | ust-kut
# Processing Record 48 of Set 12 | muskegon
# Processing Record 49 of Set 12 | fortuna
# Processing Record 50 of Set 12 | rangoon
# Processing Record 1 of Set 13 | inhambane
# Processing Record 2 of Set 13 | biak
# Processing Record 3 of Set 13 | ler
# Processing Record 4 of Set 13 | ladario
# Processing Record 5 of Set 13 | brodokalmak
# Processing Record 6 of Set 13 | ulladulla
# Processing Record 7 of Set 13 | shpykiv
# City not found. Skipping...
# Processing Record 8 of Set 13 | ancona
# Processing Record 9 of Set 13 | liwale
# Processing Record 10 of Set 13 | hamilton
# Processing Record 11 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 13 | gatesville
# Processing Record 13 of Set 13 | umm kaddadah
# Processing Record 14 of Set 13 | saurimo
# Processing Record 15 of Set 13 | aswan
# Processing Record 16 of Set 13 | barreirinhas
# Processing Record 17 of Set 13 | bay roberts
# Processing Record 18 of Set 13 | san jeronimo
# Processing Record 19 of Set 13 | coos bay
# Processing Record 20 of Set 13 | helong
# Processing Record 21 of Set 13 | kudahuvadhoo
# Processing Record 22 of Set 13 | rajura
# Processing Record 23 of Set 13 | loiza
# Processing Record 24 of Set 13 | ahipara
# Processing Record 25 of Set 13 | ciudad del maiz
# Processing Record 26 of Set 13 | miramar
# Processing Record 27 of Set 13 | tucurui
# Processing Record 28 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 13 | yingcheng
# Processing Record 30 of Set 13 | port moresby
# Processing Record 31 of Set 13 | sikonge
# Processing Record 32 of Set 13 | syamzha
# Processing Record 33 of Set 13 | mata
# Processing Record 34 of Set 13 | pierre
# Processing Record 35 of Set 13 | parthenay
# Processing Record 36 of Set 13 | oranjestad
# Processing Record 37 of Set 13 | usinsk
# Processing Record 38 of Set 13 | huarmey
# Processing Record 39 of Set 13 | coruripe
# Processing Record 40 of Set 13 | challans
# Processing Record 41 of Set 13 | manta
# Processing Record 42 of Set 13 | keetmanshoop
# Processing Record 43 of Set 13 | kristiansund
# Processing Record 44 of Set 13 | viedma
# Processing Record 45 of Set 13 | presidencia roque saenz pena
# Processing Record 46 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 48 of Set 13 | konevo
# Processing Record 49 of Set 13 | riachao das neves
# Processing Record 50 of Set 13 | balingasay
# Processing Record 1 of Set 14 | nago
# Processing Record 2 of Set 14 | skiros
# City not found. Skipping...
# Processing Record 3 of Set 14 | campoverde
# Processing Record 4 of Set 14 | itoman
# Processing Record 5 of Set 14 | agadez
# Processing Record 6 of Set 14 | argentan
# Processing Record 7 of Set 14 | rambouillet
# Processing Record 8 of Set 14 | lahaina
# Processing Record 9 of Set 14 | paro
# Processing Record 10 of Set 14 | singkang
# Processing Record 11 of Set 14 | zhovtneve
# Processing Record 12 of Set 14 | hambantota
# Processing Record 13 of Set 14 | tessalit
# Processing Record 14 of Set 14 | golden
# Processing Record 15 of Set 14 | lagoa
# Processing Record 16 of Set 14 | borama
# City not found. Skipping...
# Processing Record 17 of Set 14 | whitewater
# Processing Record 18 of Set 14 | shiyan
# Processing Record 19 of Set 14 | fayaoue
# Processing Record 20 of Set 14 | gazojak
# Processing Record 21 of Set 14 | flin flon
# Processing Record 22 of Set 14 | ayan
# Processing Record 23 of Set 14 | fengrun
# Processing Record 24 of Set 14 | srandakan
# Processing Record 25 of Set 14 | vagamo
# Processing Record 26 of Set 14 | namibe
# Processing Record 27 of Set 14 | north bend
# Processing Record 28 of Set 14 | hongjiang
# Processing Record 29 of Set 14 | roald
# Processing Record 30 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 31 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 14 | fairbanks
# Processing Record 33 of Set 14 | north battleford
# Processing Record 34 of Set 14 | verkhnevilyuysk
# Processing Record 35 of Set 14 | lawton
# Processing Record 36 of Set 14 | pokhara
# Processing Record 37 of Set 14 | nola
# Processing Record 38 of Set 14 | cermik
# Processing Record 39 of Set 14 | axim
# Processing Record 40 of Set 14 | rincon
# Processing Record 41 of Set 14 | iquique
# Processing Record 42 of Set 14 | beringovskiy
# Processing Record 43 of Set 14 | ovruch
# Processing Record 44 of Set 14 | conceicao do araguaia
# Processing Record 45 of Set 14 | cleburne
# Processing Record 46 of Set 14 | el coco
# Processing Record 47 of Set 14 | loandjili
# Processing Record 48 of Set 14 | yala
# Processing Record 49 of Set 14 | necochea
# Processing Record 50 of Set 14 | rock springs
# Processing Record 1 of Set 15 | teruel
# Processing Record 2 of Set 15 | birjand
# Processing Record 3 of Set 15 | egvekinot
# Processing Record 4 of Set 15 | saint-leu
# Processing Record 5 of Set 15 | deputatskiy
# Processing Record 6 of Set 15 | vila do maio
# Processing Record 7 of Set 15 | victor harbor
# Processing Record 8 of Set 15 | tsogni
# Processing Record 9 of Set 15 | urumqi
# Processing Record 10 of Set 15 | kargil
# Processing Record 11 of Set 15 | marzuq
# Processing Record 12 of Set 15 | huangnihe
# Processing Record 13 of Set 15 | cadillac
# Processing Record 14 of Set 15 | kiama
# Processing Record 15 of Set 15 | cabedelo
# Processing Record 16 of Set 15 | grand island
# Processing Record 17 of Set 15 | ozernovskiy
# Processing Record 18 of Set 15 | baoro
# Processing Record 19 of Set 15 | piopio
# Processing Record 20 of Set 15 | codajas
# Processing Record 21 of Set 15 | mamlyutka
# Processing Record 22 of Set 15 | novopetrovskoye
# Processing Record 23 of Set 15 | mubende
# Processing Record 24 of Set 15 | sahuaripa
# Processing Record 25 of Set 15 | abalak
# Processing Record 26 of Set 15 | hervey bay
# Processing Record 27 of Set 15 | fredericton
# Processing Record 28 of Set 15 | port augusta
# Processing Record 29 of Set 15 | katherine
# Processing Record 30 of Set 15 | kuruman
# Processing Record 31 of Set 15 | tawang
# Processing Record 32 of Set 15 | burkhala
# City not found. Skipping...
# Processing Record 33 of Set 15 | vershino-darasunskiy
# Processing Record 34 of Set 15 | sterling
# Processing Record 35 of Set 15 | makakilo city
# Processing Record 36 of Set 15 | chernyshevskiy
# Processing Record 37 of Set 15 | vanavara
# Processing Record 38 of Set 15 | agua caliente
# Processing Record 39 of Set 15 | bell ville
# Processing Record 40 of Set 15 | belturbet
# Processing Record 41 of Set 15 | curumani
# Processing Record 42 of Set 15 | port hedland
# Processing Record 43 of Set 15 | plettenberg bay
# Processing Record 44 of Set 15 | ippy
# Processing Record 45 of Set 15 | fort oglethorpe
# Processing Record 46 of Set 15 | acuna
# City not found. Skipping...
# Processing Record 47 of Set 15 | baihar
# Processing Record 48 of Set 15 | shirokiy
# Processing Record 49 of Set 15 | felipe carrillo puerto
# Processing Record 50 of Set 15 | teacapan
# Processing Record 1 of Set 16 | wajima
# Processing Record 2 of Set 16 | kjopsvik
# Processing Record 3 of Set 16 | thiers
# Processing Record 4 of Set 16 | twin falls
# Processing Record 5 of Set 16 | loikaw
# Processing Record 6 of Set 16 | ostersund
# Processing Record 7 of Set 16 | mackenzie
# Processing Record 8 of Set 16 | lahij
# Processing Record 9 of Set 16 | nyurba
# Processing Record 10 of Set 16 | camacha
# Processing Record 11 of Set 16 | atar
# Processing Record 12 of Set 16 | biltine
# Processing Record 13 of Set 16 | odienne
# Processing Record 14 of Set 16 | inongo
# Processing Record 15 of Set 16 | kharitonovo
# Processing Record 16 of Set 16 | monrovia
# Processing Record 17 of Set 16 | arlit
# Processing Record 18 of Set 16 | shaoyang
# Processing Record 19 of Set 16 | lorengau
# Processing Record 20 of Set 16 | merritt
# Processing Record 21 of Set 16 | chulumani
# Processing Record 22 of Set 16 | whitehorse
# Processing Record 23 of Set 16 | myitkyina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
# convert the array of dictionaries to a df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town -33.9258   18.4232     61.21        73          75
# 1  Punta Arenas -53.1500  -70.9167     46.51        66          75
# 2       Ushuaia -54.8000  -68.3000     47.86        49          75
# 3    Uglovskoye  51.3557   80.1942     43.18        60          17
# 4  Constitucion -35.3333  -72.4167     56.80        58           1
# 5      Hermanus -34.4187   19.2345     60.80        77           0
# 6        Barrow  71.2906 -156.7887     30.22        74          75
# 7       Mataura -46.1927  168.8643     41.49        98          19
# 8     Hithadhoo  -0.6000   73.0833     83.28        71          96
# 9     Mogadishu   2.0371   45.3438     78.24        82           0
#
#    Wind Speed CurrentDescription
# 0        1.99      broken clouds
# 1       21.85      broken clouds
# 2       14.97      broken clouds
# 3        6.04         few clouds
# 4       15.26          clear sky
# 5       15.10          clear sky
# 6       24.16         light snow
# 7        3.00         few clouds
# 8        2.17    overcast clouds
# 9       18.84          clear sky

# %%
# reorder columns
new_order = ["City", "CurrentDescription", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_order]

city_data_df.head()
# Out:
#            City CurrentDescription      Lat      Lng  Max Temp  Humidity  \
# 0     Cape Town      broken clouds -33.9258  18.4232     61.21        73
# 1  Punta Arenas      broken clouds -53.1500 -70.9167     46.51        66
# 2       Ushuaia      broken clouds -54.8000 -68.3000     47.86        49
# 3    Uglovskoye         few clouds  51.3557  80.1942     43.18        60
# 4  Constitucion          clear sky -35.3333 -72.4167     56.80        58
#
#    Cloudiness  Wind Speed
# 0          75        1.99
# 1          75       21.85
# 2          75       14.97
# 3          17        6.04
# 4           1       15.26

# %%
# create the output file
output_data_file = "WeatherPy_Database.csv"
# export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
